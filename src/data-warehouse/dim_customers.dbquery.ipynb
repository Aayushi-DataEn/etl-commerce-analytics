-- %%
CREATE table ecommerce_analytics.data_warehouse.dim_customer (
  customer_id BIGINT,
  customer_name STRING

)

select * from batch_1.data.customers;

INSERT into ecommerce_analytics.data_warehouse.dim_customer
select
customer_id,
customer_name 
from batch_1.data.customers;

select * from ecommerce_analytics.data_warehouse.dim_customer;
