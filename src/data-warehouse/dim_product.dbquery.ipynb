-- %%
CREATE or replace table ecommerce_analytics.data_warehouse.dim_product AS 
SELECT
DISTINCT
cast(product_id as string) ,
cast(product_name as string)
from batch_1.data.sales_order
where product_id is not null;

select * from ecommerce_analytics.data_warehouse.dim_product;
